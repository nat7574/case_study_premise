# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/Data Science/Projects/Case Study"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Data Science/Projects/Case Study

# %%
# !git config --global credential.helper store

# %%
from getpass import getpass
token = getpass('Enter your GitHub token: ')

# %%
# !git remote set-url origin https://{token}github.com/nat7574/case_study_premise.git
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
import subprocess
import os

# Set credentials via environment (more secure than hardcoding)
#token = os.environ.get('GITHUB_TOKEN')  # Set this in Colab Secrets
repo_url = f"https://{token}@github.com/nat7574/case_study_premise.git"

# Clone
subprocess.run(['git', 'clone', repo_url, 'case_study_premise'], check=True)
os.chdir('case_study_premise')

# Configure git
subprocess.run(['git', 'config', 'user.email', 'email@example.com'], check=True)
subprocess.run(['git', 'config', 'user.name', 'Your Name'], check=True)

# Copy notebook (adjust path as needed)
subprocess.run(['cp', '/content/drive/MyDrive/Data Science/Projects/Case Study/medical_claims.ipynb', './'], check=True)

# Push to GitHub
subprocess.run(['git', 'add', '.'], check=True)
subprocess.run(['git', 'commit', '-m', 'Add notebook'], check=True)
subprocess.run(['git', 'push', '-u', 'origin', 'main'], check=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2071/1704342683.py in <cell line: 0>()
#       1 import subprocess
#       2 import os
# ----> 3 token= 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
#       4 # Set credentials via environment (more secure than hardcoding)
#       5 #token = os.environ.get('GITHUB_TOKEN')  # Set this in Colab Secrets
#
# NameError: name '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' is not defined
